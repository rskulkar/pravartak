# %%
from graph import build_graph, search_node, intake_node
from state import GraphState, BuyerProfile
from inventory import search_properties
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from graph import build_graph, search_node, intake_node
#       2 from state import GraphState, BuyerProfile
#       3 from inventory import search_properties
#
# File ~/Library/CloudStorage/OneDrive-Personal/projects/github/pravartak/assignments/week11/real_estate_agent/graph.py:3
#       1 import json
#       2 import os
# ----> 3 from dotenv import load_dotenv
#       4 from anthropic import Anthropic
#       5 from langgraph.graph import StateGraph, START, END
#
# ModuleNotFoundError: No module named 'dotenv'

# %%
print("=" * 60)
print("DIAGNOSTIC SMOKE TEST — DIRECORY INVERNTORY CHECK")
print("=" * 60)

# Scenario A — clean run, no recovery expected
print("\nSCENARIO A — First-time buyer, Whitefield, ₹80L, 2BHK")
print("-" * 60)
